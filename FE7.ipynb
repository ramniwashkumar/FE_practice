# %%
df=pd.read_csv(r'C:\Users\ramni\OneDrive\Documents\train.csv')
df
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
X=df.iloc[:,:-1]
y=df['price_range']

# %%
X.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2   2         20       756  2549     9     7         19
# 1        136        3   6        905      1988  2631    17     3          7
# 2        145        5   6       1263      1716  2603    11     2          9
# 3        131        6   9       1216      1786  2769    16     8         11
# 4        141        2  14       1208      1212  1411     8     2         15
#
#    three_g  touch_screen  wifi
# ...

# %%
y.head()
# Out:
# 0    1
# 1    2
# 2    2
# 3    2
# 4    1
# Name: price_range, dtype: int64

# %%
from sklearn.datasets import load_boston
df = load_boston()

# %%
print(df.DESCR)
# Out:
# .. _boston_dataset:
#
# Boston house prices dataset
# ---------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
# ...

# %%
print(df.target)
# Out:
# [24.  21.6 34.7 33.4 36.2 28.7 22.9 27.1 16.5 18.9 15.  18.9 21.7 20.4
#  18.2 19.9 23.1 17.5 20.2 18.2 13.6 19.6 15.2 14.5 15.6 13.9 16.6 14.8
#  18.4 21.  12.7 14.5 13.2 13.1 13.5 18.9 20.  21.  24.7 30.8 34.9 26.6
#  25.3 24.7 21.2 19.3 20.  16.6 14.4 19.4 19.7 20.5 25.  23.4 18.9 35.4
#  24.7 31.6 23.3 19.6 18.7 16.  22.2 25.  33.  23.5 19.4 22.  17.4 20.9
#  24.2 21.7 22.8 23.4 24.1 21.4 20.  20.8 21.2 20.3 28.  23.9 24.8 22.9
#  23.9 26.6 22.5 22.2 23.6 28.7 22.6 22.  22.9 25.  20.6 28.4 21.4 38.7
#  43.8 33.2 27.5 26.5 18.6 19.3 20.1 19.5 19.5 20.4 19.8 19.4 21.7 22.8
#  18.8 18.7 18.5 18.3 21.2 19.2 20.4 19.3 22.  20.3 20.5 17.3 18.8 21.4
#  15.7 16.2 18.  14.3 19.2 19.6 23.  18.4 15.6 18.1 17.4 17.1 13.3 17.8
#  14.  14.4 13.4 15.6 11.8 13.8 15.6 14.6 17.8 15.4 21.5 19.6 15.3 19.4
#  17.  15.6 13.1 41.3 24.3 23.3 27.  50.  50.  50.  22.7 25.  50.  23.8
#  23.8 22.3 17.4 19.1 23.1 23.6 22.6 29.4 23.2 24.6 29.9 37.2 39.8 36.2
# ...

# %%
boston = pd.DataFrame(df.data, columns=df.feature_names)
boston.head(20)
# Out:
#        CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD    TAX  \
# 0   0.00632  18.0   2.31   0.0  0.538  6.575   65.2  4.0900  1.0  296.0
# 1   0.02731   0.0   7.07   0.0  0.469  6.421   78.9  4.9671  2.0  242.0
# 2   0.02729   0.0   7.07   0.0  0.469  7.185   61.1  4.9671  2.0  242.0
# 3   0.03237   0.0   2.18   0.0  0.458  6.998   45.8  6.0622  3.0  222.0
# 4   0.06905   0.0   2.18   0.0  0.458  7.147   54.2  6.0622  3.0  222.0
# 5   0.02985   0.0   2.18   0.0  0.458  6.430   58.7  6.0622  3.0  222.0
# 6   0.08829  12.5   7.87   0.0  0.524  6.012   66.6  5.5605  5.0  311.0
# 7   0.14455  12.5   7.87   0.0  0.524  6.172   96.1  5.9505  5.0  311.0
# 8   0.21124  12.5   7.87   0.0  0.524  5.631  100.0  6.0821  5.0  311.0
# 9   0.17004  12.5   7.87   0.0  0.524  6.004   85.9  6.5921  5.0  311.0
# 10  0.22489  12.5   7.87   0.0  0.524  6.377   94.3  6.3467  5.0  311.0
# 11  0.11747  12.5   7.87   0.0  0.524  6.009   82.9  6.2267  5.0  311.0
# ...

# %%
##program for converting video to audio
import moviepy.editor as np 
def ex(vp,an):
    clip=np.VideoFileClip(vp)
    clip.audio.write_audiofile(an)

# %%
vp=r"C:\Users\ramni\Downloads\Actions - Devil's Words.stem.mp4" 
an="ex.mp3" 
ex(vp,an)
# Out:
# chunk:   0%|                                                                        | 0/4336 [00:00<?, ?it/s, now=None]
# MoviePy - Writing audio in ex.mp3
# MoviePy - Done.

# %%
df=pd.read_csv(r'D:\train.csv')
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
d=df.groupby('MSZoning')
d

# %%
for i,j in d:
    print(i)
    print(j)
# Out:
# C (all)
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 30      31          70  C (all)         50.0     8500   Pave  Pave      Reg
# 88      89          50  C (all)        105.0     8470   Pave   NaN      IR1
# 93      94         190  C (all)         60.0     7200   Pave   NaN      Reg
# 495    496          30  C (all)         60.0     7879   Pave   NaN      Reg
# 557    558          50  C (all)         60.0    11040   Pave   NaN      Reg
# 711    712          50  C (all)         66.0     8712   Pave  Pave      Reg
# 812    813          20  C (all)         66.0     8712   Grvl   NaN      Reg
# 916    917          20  C (all)         50.0     9000   Pave   NaN      Reg
# 1061  1062          30  C (all)        120.0    18000   Grvl   NaN      Reg
# 1279  1280          50  C (all)         60.0     7500   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# ...

# %%
d=df.groupby('MSSubClass')['SalePrice'].count()
d
# Out:
# MSSubClass
# 20     536
# 30      69
# 40       4
# 45      12
# 50     144
# 60     299
# 70      60
# 75      16
# 80      58
# 85      20
# 90      52
# 120     87
# 160     63
# 180     10
# 190     30
# Name: SalePrice, dtype: int64

# %%
d=df.groupby('MSSubClass').count()
d
# Out:
#              Id  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# MSSubClass
# 20          536       536          437      536     536      5       536
# 30           69        69           63       69      69     12        69
# 40            4         4            3        4       4      1         4
# 45           12        12           12       12      12      1        12
# 50          144       144          128      144     144     24       144
# 60          299       299          230      299     299      2       299
# 70           60        60           55       60      60     16        60
# 75           16        16           15       16      16      3        16
# 80           58        58           38       58      58      0        58
# 85           20        20           14       20      20      0        20
# 90           52        52           47       52      52      2        52
# 120          87        87           67       87      87      4        87
# ...

# %%
df['MSSubClass'].unique()
# Out:
# array([ 60,  20,  70,  50, 190,  45,  90, 120,  30,  85,  80, 160,  75,
#        180,  40], dtype=int64)

# %%
d=df.groupby('MSSubClass')['YrSold'].count()
d
# Out:
# MSSubClass
# 20     536
# 30      69
# 40       4
# 45      12
# 50     144
# 60     299
# 70      60
# 75      16
# 80      58
# 85      20
# 90      52
# 120     87
# 160     63
# 180     10
# 190     30
# Name: YrSold, dtype: int64

# %%
d=df.groupby('MSSubClass')['SalePrice','Alley'].count()
d
# Out:
# <ipython-input-23-4ca0ae862b7e>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   d=df.groupby('MSSubClass')['SalePrice','Alley'].count()
#             SalePrice  Alley
# MSSubClass
# 20                536      5
# 30                 69     12
# 40                  4      1
# 45                 12      1
# 50                144     24
# 60                299      2
# 70                 60     16
# 75                 16      3
# 80                 58      0
# 85                 20      0
# 90                 52      2
# 120                87      4
# 160                63     15
# 180                10      0
# 190                30      6

# %%
d=df.groupby('MSSubClass').count()
d
# Out:
#              Id  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# MSSubClass
# 20          536       536          437      536     536      5       536
# 30           69        69           63       69      69     12        69
# 40            4         4            3        4       4      1         4
# 45           12        12           12       12      12      1        12
# 50          144       144          128      144     144     24       144
# 60          299       299          230      299     299      2       299
# 70           60        60           55       60      60     16        60
# 75           16        16           15       16      16      3        16
# 80           58        58           38       58      58      0        58
# 85           20        20           14       20      20      0        20
# 90           52        52           47       52      52      2        52
# 120          87        87           67       87      87      4        87
# ...

# %%
d=df.groupby('MSSubClass')
d

# %%
for i,j in d: 
    print(i)
    print(len(j))
# Out:
# 20
# 536
# 30
# 69
# 40
# 4
# 45
# 12
# 50
# 144
# 60
# 299
# 70
# 60
# 75
# 16
# 80
# 58
# 85
# 20
# 90
# 52
# 120
# 87
# 160
# 63
# 180
# 10
# 190
# 30

# %%
for i,j in d: 
    print(i)
    print(j["Alley"])
# Out:
# 20
# 1        NaN
# 6        NaN
# 10       NaN
# 12       NaN
# 13       NaN
#         ...
# 1453     NaN
# 1454    Pave
# 1456     NaN
# 1458     NaN
# 1459     NaN
# Name: Alley, Length: 536, dtype: object
# 30
# 29       NaN
# 68       NaN
# 92      Grvl
# 98       NaN
# 106     Grvl
#         ...
# 1380    Grvl
# 1383     NaN
# 1428     NaN
# 1432    Grvl
# 1443     NaN
# Name: Alley, Length: 69, dtype: object
# 40
# 164     Pave
# 589      NaN
# 873      NaN
# 1270     NaN
# Name: Alley, dtype: object
# 45
# 15       NaN
# 21      Grvl
# 127      NaN
# 163      NaN
# 325      NaN
# 383      NaN
# 437      NaN
# 514      NaN
# 555      NaN
# 617      NaN
# 826      NaN
# 1069     NaN
# Name: Alley, dtype: object
# 50
# 5        NaN
# 8        NaN
# 46       NaN
# 51       NaN
# 69       NaN
#         ...
# 1404    Grvl
# 1411     NaN
# 1414    Pave
# 1427    Grvl
# 1448     NaN
# Name: Alley, Length: 144, dtype: object
# 60
# 0       NaN
# 2       NaN
# 4       NaN
# ...
